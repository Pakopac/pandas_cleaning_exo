# %% [markdown]
# ## Pandas cleaning

# %%
import pandas

# %%
path = "https://raw.githubusercontent.com/remiconnesson/datasets/master/data/world-cities/world-cities.csv"
df = pandas.read_csv(path)
df.head()
# Out:
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %% [markdown]
# ## exo 1

# %%
import pandas as pd
chemin = "chemin/qui/nexistepas"
data = pd.read_csv(chemin)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f5b3c08b4a7e> in <module>
#       1 import pandas as pd
#       2 chemin = "chemin/qui/nexistepas"
# ----> 3 data = pd.read_csv(chemin)
#
# /mnt/d/python/venv/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %% [markdown]
# le fichier 'chemin/qui/nexistepas' n'existe pas.
#
# il faut changer le chemin avec un fichier existant.

# %% [markdown]
# ## exo 2

# %%
import pandas as pd
chemin = "https://bit.ly/world-cities-dirty-v1"
data = pd.read_csv(chemin)
data.head()
# Out:
#        les Escaldes               Andorra Escaldes-Engordany  3040051
# 0  Andorra la Vella               Andorra   Andorra la Vella  3041563
# 1    Umm al Qaywayn  United Arab Emirates     Umm al Qaywayn   290594
# 2    Ras al-Khaimah  United Arab Emirates    Raʼs al Khaymah   291074
# 3      Khawr Fakkān  United Arab Emirates       Ash Shāriqah   291696
# 4             Dubai  United Arab Emirates              Dubai   292223

# %% [markdown]
# les nom de colonnes ne sont pas les bons

# %%
colnames=['name', 'country', 'subcountry', 'geonameid'] 
pd.read_csv(chemin, names=colnames, header=None)
# Out:
#                     name               country           subcountry  geonameid
# 0           les Escaldes               Andorra   Escaldes-Engordany    3040051
# 1       Andorra la Vella               Andorra     Andorra la Vella    3041563
# 2         Umm al Qaywayn  United Arab Emirates       Umm al Qaywayn     290594
# 3         Ras al-Khaimah  United Arab Emirates      Raʼs al Khaymah     291074
# 4           Khawr Fakkān  United Arab Emirates         Ash Shāriqah     291696
# 5                  Dubai  United Arab Emirates                Dubai     292223
# 6      Dibba Al-Fujairah  United Arab Emirates          Al Fujayrah     292231
# 7          Dibba Al-Hisn  United Arab Emirates          Al Fujayrah     292239
# 8                Sharjah  United Arab Emirates         Ash Shāriqah     292672
# 9              Ar Ruways  United Arab Emirates            Abu Dhabi     292688
# 10           Al Fujayrah  United Arab Emirates          Al Fujayrah     292878
# ...

# %% [markdown]
# ## exo 3

# %%
import pandas as pd
chemin = "https://bit.ly/world-cities-dirty-v2"
data = pd.read_csv(chemin)
data
# Out:
#                                                                                                                                                                                                                                                                                                                               Lorem ipsum dolor sit amet  \
# Sed ut perspiciatis unde omnis iste natus error...  totam rem aperiam                                  eaque ipsa quae ab illo inventore veritatis et...  sed quia consequuntur magni dolores eos qui ra...  qui dolorem ipsum quia dolor sit amet  consectetur                                                                           adipisci velit
# ...

# %%
colnames=['name', 'country', 'subcountry', 'geonameid'] 
data = pd.read_csv(chemin, names=colnames, skiprows=3, skipfooter=1)
data
# Out:
# /mnt/d/python/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#                     name               country           subcountry  geonameid
# 0           les Escaldes               Andorra   Escaldes-Engordany    3040051
# 1       Andorra la Vella               Andorra     Andorra la Vella    3041563
# 2         Umm al Qaywayn  United Arab Emirates       Umm al Qaywayn     290594
# 3         Ras al-Khaimah  United Arab Emirates      Raʼs al Khaymah     291074
# 4           Khawr Fakkān  United Arab Emirates         Ash Shāriqah     291696
# 5                  Dubai  United Arab Emirates                Dubai     292223
# 6      Dibba Al-Fujairah  United Arab Emirates          Al Fujayrah     292231
# 7          Dibba Al-Hisn  United Arab Emirates          Al Fujayrah     292239
# ...

# %% [markdown]
# ## exo 4

# %%
import pandas as pd
chemin = "https://bit.ly/world-cities-dirty-v3"
data = pd.read_csv(chemin)
data
# Out:
#          les Escaldes|Andorra|Escaldes-Engordany|3040051
# 0      Andorra la Vella|Andorra|Andorra la Vella|3041563
# 1      Umm al Qaywayn|United Arab Emirates|Umm al Qay...
# 2      Ras al-Khaimah|United Arab Emirates|Raʼs al Kh...
# 3      Khawr Fakkān|United Arab Emirates|Ash Shāriqah...
# 4                Dubai|United Arab Emirates|Dubai|292223
# 5      Dibba Al-Fujairah|United Arab Emirates|Al Fuja...
# 6      Dibba Al-Hisn|United Arab Emirates|Al Fujayrah...
# 7       Sharjah|United Arab Emirates|Ash Shāriqah|292672
# 8        Ar Ruways|United Arab Emirates|Abu Dhabi|292688
# 9      Al Fujayrah|United Arab Emirates|Al Fujayrah|2...
# 10          Al Ain|United Arab Emirates|Abu Dhabi|292913
# 11               Ajman|United Arab Emirates|Ajman|292932
# 12     Adh Dhayd|United Arab Emirates|Ash Shāriqah|29...
# 13       Abu Dhabi|United Arab Emirates|Abu Dhabi|292968
# 14                     Zaranj|Afghanistan|Nīmrūz|1120985
# ...

# %%
colnames=['name', 'country', 'subcountry', 'geonameid'] 
data = pd.read_csv(chemin, names=colnames ,sep="|")
data
# Out:
#                     name               country           subcountry  geonameid
# 0           les Escaldes               Andorra   Escaldes-Engordany    3040051
# 1       Andorra la Vella               Andorra     Andorra la Vella    3041563
# 2         Umm al Qaywayn  United Arab Emirates       Umm al Qaywayn     290594
# 3         Ras al-Khaimah  United Arab Emirates      Raʼs al Khaymah     291074
# 4           Khawr Fakkān  United Arab Emirates         Ash Shāriqah     291696
# 5                  Dubai  United Arab Emirates                Dubai     292223
# 6      Dibba Al-Fujairah  United Arab Emirates          Al Fujayrah     292231
# 7          Dibba Al-Hisn  United Arab Emirates          Al Fujayrah     292239
# 8                Sharjah  United Arab Emirates         Ash Shāriqah     292672
# 9              Ar Ruways  United Arab Emirates            Abu Dhabi     292688
# 10           Al Fujayrah  United Arab Emirates          Al Fujayrah     292878
# ...

# %% [markdown]
# Afficher lignes, colonnes

# %%
data.shape
# Out:
# (23018, 4)

# %% [markdown]
# Afficher nom des colonnes + types

# %%
data.dtypes
# Out:
# name          object
# country       object
# subcountry    object
# geonameid      int64
# dtype: object

# %% [markdown]
# Comparer le début et la fin

# %%
data.head()
# Out:
#                name               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %%
data.tail()
# Out:
#               name   country           subcountry  geonameid
# 23013     Bulawayo  Zimbabwe             Bulawayo     894701
# 23014      Bindura  Zimbabwe  Mashonaland Central     895061
# 23015   Beitbridge  Zimbabwe   Matabeleland South     895269
# 23016      Epworth  Zimbabwe               Harare    1085510
# 23017  Chitungwiza  Zimbabwe               Harare    1106542

# %% [markdown]
# Nombres de valeurs manquantes par colonnes

# %%
data.isna().sum()
# Out:
# name           0
# country        0
# subcountry    26
# geonameid      0
# dtype: int64

# %%
cheminBC = "https://bit.ly/bitcoin-data"
dataBC = pd.read_csv(cheminBC)

# %%
dataBC.shape
# Out:
# (33, 7)

# %%
dataBC.dtypes
# Out:
# Date           object
# Open*         float64
# High          float64
# Low           float64
# Close**       float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
dataBC.head()
# Out:
#           Date    Open*     High      Low  Close**        Volume    Market Cap
# 0  Jan 14 2020  8140.93  8879.51  8140.93  8827.76  4.484178e+10  1.603195e+11
# 1  Jan 13 2020  8189.77  8197.79  8079.70  8144.19  2.248291e+10  1.478905e+11
# 2  Jan 12 2020  8033.26  8200.06  8009.06  8192.49  2.290344e+10  1.487530e+11
# 3  Jan 11 2020  8162.19  8218.36  8029.64  8037.54  2.552117e+10  1.459242e+11
# 4  Jan 10 2020  7878.31  8166.55  7726.77  8166.55  2.871458e+10  1.482499e+11

# %%
dataBC.tail()
# Out:
#                                    Date    Open*     High      Low  Close**  \
# 28                          Dec 17 2019  6931.32  6964.07  6587.97  6640.52
# 29                          Dec 16 2019  7153.66  7171.17  6903.68  6932.48
# 30                          Dec 15 2019  7124.24  7181.08  6924.38  7152.30
# 31  * Earliest data in range (UTC time)      NaN      NaN      NaN      NaN
# 32   ** Latest data in range (UTC time)      NaN      NaN      NaN      NaN
#
#           Volume    Market Cap
# 28  2.236380e+10  1.202342e+11
# 29  2.021327e+10  1.255156e+11
# 30  1.688113e+10  1.294814e+11
# 31           NaN           NaN
# 32           NaN           NaN

# %%
dataBC.isna().sum()
# Out:
# Date          0
# Open*         2
# High          2
# Low           2
# Close**       2
# Volume        2
# Market Cap    2
# dtype: int64

# %%
dataBC['Open'] = dataBC['Open*']

# %%
dataBC.drop('Open*', axis="columns", inplace=True)

# %%
dataBC = dataBC.drop('Open*', axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-ebf5028552e2> in <module>
# ----> 1 dataBC = dataBC.drop('Open*', axis='columns')
#
# /mnt/d/python/venv/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /mnt/d/python/venv/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
dataBC
# Out:
#                                    Date     High      Low  Close**  \
# 0                           Jan 14 2020  8879.51  8140.93  8827.76
# 1                           Jan 13 2020  8197.79  8079.70  8144.19
# 2                           Jan 12 2020  8200.06  8009.06  8192.49
# 3                           Jan 11 2020  8218.36  8029.64  8037.54
# 4                           Jan 10 2020  8166.55  7726.77  8166.55
# 5                           Jan 09 2020  8082.30  7842.40  7879.07
# 6                           Jan 08 2020  8396.74  7956.77  8079.86
# 7                           Jan 07 2020  8178.22  7768.23  8163.69
# 8                           Jan 06 2020  7781.87  7409.29  7769.22
# 9                           Jan 05 2020  7544.50  7400.54  7411.32
# 10                          Jan 04 2020  7427.39  7309.51  7410.66
# 11                          Jan 03 2020  7413.72  6915.00  7344.88
# 12                          Jan 02 2020  7212.16  6935.27  6985.47
# ...

# %%
toy = pd.DataFrame({'a': [1,2], 'b': [3,4]})

# %%
toy
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %% [markdown]
# Méthode 1 : Rename + Mapper

# %%
toy.rename(str.upper, axis='columns', inplace=True)

# %%
toy
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# Méthode 2 : avec le module str

# %%
toy.columns = toy.columns.str.upper()
